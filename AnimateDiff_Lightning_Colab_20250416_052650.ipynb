# %% [markdown]
# # 🎞️ AnimateDiff Lightning (ByteDance) - Google Colab
# This notebook sets up AnimateDiff with ByteDance's Lightning model for fast animation generation from text prompts.
#
# Make sure to **select GPU** in Colab: `Runtime > Change runtime type > GPU`

# %%
# ✅ Step 1: Clone the AnimateDiff repo
# !git clone https://github.com/guoyww/AnimateDiff.git
# %cd AnimateDiff

# %%
# ✅ Step 2: Install dependencies
# !pip install -r requirements.txt

# %%
# ✅ Step 3: Download the Lightning model (2-step)
# !mkdir -p models/Motion_Module
# !wget -O models/Motion_Module/animatediff_lightning_2step_diffusers.safetensors https://huggingface.co/ByteDance/AnimateDiff-Lightning/resolve/main/animatediff_lightning_2step_diffusers.safetensors

# %%
# ✅ Step 4: Run animation generation using a sample config
# You can replace the config path with your own
# !python -m scripts.animate --config configs/prompts/1_animate/1_1_animate_RealisticVision.yaml
